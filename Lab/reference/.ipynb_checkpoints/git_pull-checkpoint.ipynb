# %%
# !git pull
# Out:
# remote: Counting objects: 48, done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 48 (delta 24), reused 46 (delta 22), pack-reused 0
# Unpacking objects: 100% (48/48), done.
# From https://github.com/telescopeuser/GCP-SamGu
#    258eb71..0140ab1  master     -> origin/master
# Updating 258eb71..0140ab1
# Fast-forward
#  .ipynb_checkpoints/README-checkpoint.ipynb         | 265 +++++++++++++++++++++
#  .../Lab_Image_Analysis_v05-checkpoint.ipynb        | 133 +++++++----
#  Lab/Lab_Image_Analysis_v05.ipynb                   | 133 +++++++----
#  Lab/images/abnormal_valve_01.jpg                   | Bin 18160 -> 35061 bytes
#  Lab/images/abnormal_valve_02.jpg                   | Bin 41594 -> 15489 bytes
#  Lab/images/abnormal_valve_03.jpg                   | Bin 22489 -> 18160 bytes
#  Lab/images/abnormal_valve_04.jpg                   | Bin 24615 -> 41594 bytes
#  Lab/images/abnormal_valve_05.jpg                   | Bin 20404 -> 22489 bytes
# ...
